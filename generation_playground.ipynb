# %%
import time, subprocess, re

# download streamlit app
# !wget -q https://raw.githubusercontent.com/bhaveshadhikari/playground/main/app.py -O /content/app.py

# clean up any old cloudflared files
# !rm -f cloudflared cloudflared-linux-amd64 cloudflared-linux-amd64.* nohup.out

# install streamlit
# !pip install -q streamlit

# download and start cloudflare tunnel
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 -O cloudflared
# !chmod +x cloudflared
# !nohup ./cloudflared tunnel --url http://localhost:8501 --no-autoupdate &

# wait for tunnel to initialize
time.sleep(10)

# extract and display the tunnel URL
# !grep -o 'https://.*\.trycloudflare.com' nohup.out | head -n 1 | xargs -I {} echo "Playground Url: {}"

# run Streamlit app in background
# !streamlit run /content/app.py --theme.base="light" &>/content/logs.txt &
# Out:
# nohup: appending output to 'nohup.out'
# Playground Url: https://friendship-cheap-favour-papers.trycloudflare.com
